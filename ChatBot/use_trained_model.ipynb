# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
import os

# %%
working_dir = "/content/drive/MyDrive/transformers/Ecommerce/ChatBot"

# %%
os.chdir(working_dir)

# %%
os.getcwd()
# Out:
# '/content/drive/MyDrive/transformers/Ecommerce/ChatBot'

# %%
# !ls
# Out:
# checkpoint-255	estore_qa.zip  training_model_for_chatbot.ipynb
# estore_qa.csv	model_dir      use_trained_model.ipynb

# %%
tokenizer = AutoTokenizer.from_pretrained("./model_dir")
model= AutoModelForCausalLM.from_pretrained("./model_dir")
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]

# %%
def ask_chatbot(model, tokenizer, user_prompt):
    tokenizer.pad_token_id = tokenizer.eos_token_id
    inputs = tokenizer(user_prompt, return_tensors= "pt", max_length=512, padding=True, truncation=True)
    input_ids = inputs["input_ids"]
    attention_mask = inputs["attention_mask"]
    outputs = model.generate(
        input_ids = input_ids,
        attention_mask = attention_mask,
        max_length= 300,
        pad_token_id= tokenizer.eos_token_id,
        repetition_penalty =1.3
    )
    answer = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return answer

# %%
print(ask_chatbot(model, tokenizer, "Do you have a physical store?"))
# Out:
# Do you have a physical store?No, we are an online-only company. Contact us for more information.

# %%
print(ask_chatbot(model, tokenizer, "Any physical store?"))
# Out:
# Any physical store?No, we are an online-only company. Contact us for more information about digital products and promotions!

# %%
print(ask_chatbot(model, tokenizer, "What are the payment options available?"))
# Out:
# What are the payment options available?We accept credit/debit cards, PayPal, and bank transfers. Check our checkout page for details.

# %%
print(ask_chatbot(model, tokenizer, " payment options"))
# Out:
#  payment options available?Yes, we offer digital purchase plans that can be purchased online. Contact us for details.
